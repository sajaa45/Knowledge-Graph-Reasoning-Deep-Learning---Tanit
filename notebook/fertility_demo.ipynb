# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/tanit-medical-reasoner.zip -d /content/tanit-medical-reasoner/
# Out:
# Archive:  /content/drive/MyDrive/tanit-medical-reasoner.zip
#    creating: /content/tanit-medical-reasoner/.ipynb_checkpoints/
#    creating: /content/tanit-medical-reasoner/data/
#    creating: /content/tanit-medical-reasoner/models/
#    creating: /content/tanit-medical-reasoner/train/
#    creating: /content/tanit-medical-reasoner/unsloth_compiled_cache/
#   inflating: /content/tanit-medical-reasoner/final_mix_data.zip
#   inflating: /content/tanit-medical-reasoner/models.zip
#   inflating: /content/tanit-medical-reasoner/requirements.txt
#    creating: /content/tanit-medical-reasoner/unsloth_compiled_cache/.locks/
#    creating: /content/tanit-medical-reasoner/unsloth_compiled_cache/__pycache__/
#   inflating: /content/tanit-medical-reasoner/unsloth_compiled_cache/UnslothNashMDTrainer.py
#   inflating: /content/tanit-medical-reasoner/unsloth_compiled_cache/BatchNorm2d.py
#   inflating: /content/tanit-medical-reasoner/unsloth_compiled_cache/UnslothPPOTrainer.py
# ...

# %%
cd /content/tanit-medical-reasoner
# Out:
# /content/tanit-medical-reasoner

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 44.2 MB/s eta 0:00:00
# ...

# %%
# !pip install --no-deps unsloth
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.3/359.3 kB 14.4 MB/s eta 0:00:00
# ...

# %%
# !pip install unsloth_zoo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.0/288.0 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 139.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 38.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 55.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
# ...

# %%
# !python inference/stream_medical_cot.py --case_id 1 --temperature 0.8
# Out:
# /content/tanit-medical-reasoner/inference/stream_medical_cot.py:2: UserWarning: WARNING: Unsloth should be imported before transformers to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-12-07 18:23:17.854806: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-07 18:23:17.872647: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python inference/stream_medical_cot.py --case_id 2 --temperature 0.8
# Out:
# /content/tanit-medical-reasoner/inference/stream_medical_cot.py:2: UserWarning: WARNING: Unsloth should be imported before transformers to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-12-07 18:24:46.045961: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-07 18:24:46.064030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python inference/stream_medical_cot.py --case_id 3 --temperature 0.8
# Out:
# /content/tanit-medical-reasoner/inference/stream_medical_cot.py:2: UserWarning: WARNING: Unsloth should be imported before transformers to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-12-07 18:31:34.651720: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-07 18:31:34.670064: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python inference/stream_medical_cot.py --case_id 4 --temperature 0.8
# Out:
# /content/tanit-medical-reasoner/inference/stream_medical_cot.py:2: UserWarning: WARNING: Unsloth should be imported before transformers to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-12-07 18:28:28.589314: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-07 18:28:28.606903: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python inference/stream_medical_cot.py --case_id 5 --temperature 0.8
# Out:
# /content/tanit-medical-reasoner/inference/stream_medical_cot.py:2: UserWarning: WARNING: Unsloth should be imported before transformers to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-12-07 18:37:36.176439: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-07 18:37:36.195053: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
